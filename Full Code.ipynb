# %%
import pandas as pd
import ast
import altair as alt
from vega_datasets import data

# %% [markdown]
# # LibreBOR insolvencias
#
# ## 1. Get Flat Data

# %%
filename = "data/insolvencias_2021.04.20"
json_df = pd.read_json(filename + '.json', encoding='UTF-8')
df = json_df

# %%
json_df
# Out:
#                                             insolvencias
# 0      {'date': '2009-05-27T00:00:00Z', 'company': [{...
# 1      {'date': '2009-06-11T00:00:00Z', 'company': [{...
# 2      {'date': '2010-11-02T00:00:00Z', 'company': [{...
# 3      {'date': '2011-03-16T00:00:00Z', 'company': [{...
# 4      {'date': '2010-06-09T00:00:00Z', 'company': [{...
# ...                                                  ...
# 54281  {'date': '2021-04-09T00:00:00Z', 'company': [{...
# 54282  {'date': '2021-04-05T00:00:00Z', 'company': [{...
# 54283  {'date': '2021-04-13T00:00:00Z', 'company': [{...
# 54284  {'date': '2021-04-12T00:00:00Z', 'company': [{...
# 54285  {'date': '2021-04-09T00:00:00Z', 'company': [{...
#
# [54286 rows x 1 columns]

# %%
df_i = df.insolvencias.apply(pd.Series)
df_i["Company"] = [ast.literal_eval(str(x).replace("[","").replace("]","")) for x in df_i.company]
df_i_company = df_i.join(df_i.Company.apply(pd.Series))
df_i_company

df_i_c = df_i_company
df_i_c["Announcements"] = [ast.literal_eval(str(x).replace("[","").replace("]","")) for x in df_i_c.announcements]
df_i_c.Announcements.apply(pd.Series)
df_full = df_i_c.join(df_i_c.Announcements.apply(pd.Series))
df_full
# Out:
#                        date  \
# 0      2009-05-27T00:00:00Z
# 1      2009-06-11T00:00:00Z
# 2      2010-11-02T00:00:00Z
# 3      2011-03-16T00:00:00Z
# 4      2010-06-09T00:00:00Z
# ...                     ...
# 54281  2021-04-09T00:00:00Z
# 54282  2021-04-05T00:00:00Z
# 54283  2021-04-13T00:00:00Z
# 54284  2021-04-12T00:00:00Z
# 54285  2021-04-09T00:00:00Z
#
#                                                  company  \
# 0      [{'slug_company': 'aden-financiero-asegurador'...
# 1      [{'slug_company': 'fabricacion-de-bisagras', '...
# 2      [{'slug_company': 'tubos-mariño', 'province': ...
# 3      [{'slug_company': 'alas-aluminium', 'province'...
# 4      [{'slug_company': 'r-c-informatica-y-software'...
# ...                                                  ...
# 54281  [{'slug_company': 'novocat-farma', 'province':...
# 54282  [{'slug_company': 'muebles-el-palacio-sa-labor...
# 54283  [{'slug_company': 'semilleros-fuente-alamo', '...
# 54284  [{'slug_company': 'gestysa-empresarial', 'prov...
# 54285  [{'slug_company': 'vitogo-sports', 'province':...
#
#                                            announcements  \
# 0      [{'text': 'Cambio del Organo de Administración...
# 1      [{'text': 'Procedimiento concursal 145.8/2009....
# 2      [{'text': 'Procedimiento concursal 530/2010. F...
# 3      [{'text': 'Procedimiento concursal 0000044/201...
# 4      [{'text': 'Conforme al artículo 274.5 de la Le...
# ...                                                  ...
# 54281  [{'text': 'JUZGADO SOCIAL 3 DE SANTIAGO DE COM...
# 54282  [{'text': 'DECLARACION DE SITUACION DE INSOLVE...
# 54283  [{'text': 'Mandamiento remitido por el Juzgado...
# 54284  [{'text': 'Por Decreto 86/2020 de fecha 27/02/...
# 54285  [{'text': 'JUZGADO SOCIAL 30 DE BARCELONA, RES...
#
#                                                  Company  \
# 0      {'slug_company': 'aden-financiero-asegurador',...
# 1      {'slug_company': 'fabricacion-de-bisagras', 'p...
# 2      {'slug_company': 'tubos-mariño', 'province': '...
# 3      {'slug_company': 'alas-aluminium', 'province':...
# 4      {'slug_company': 'r-c-informatica-y-software',...
# ...                                                  ...
# 54281  {'slug_company': 'novocat-farma', 'province': ...
# 54282  {'slug_company': 'muebles-el-palacio-sa-labora...
# 54283  {'slug_company': 'semilleros-fuente-alamo', 'p...
# 54284  {'slug_company': 'gestysa-empresarial', 'provi...
# 54285  {'slug_company': 'vitogo-sports', 'province': ...
#
#                         slug_company   province  \
# 0         aden-financiero-asegurador     Madrid
# 1            fabricacion-de-bisagras  Barcelona
# 2                       tubos-mariño    Cáceres
# 3                     alas-aluminium   Asturias
# 4         r-c-informatica-y-software       Jaén
# ...                              ...        ...
# 54281                  novocat-farma  Barcelona
# 54282  muebles-el-palacio-sa-laboral    Segovia
# 54283        semilleros-fuente-alamo     Murcia
# 54284            gestysa-empresarial    Granada
# 54285                  vitogo-sports  Barcelona
#
#                                                  purpose     status  \
# 0      La realización de actividades de consultoría y...     active
# 1                                                    NaN     active
# 2                                                    NaN   inactive
# 3                                                    NaN  dissolved
# 4                                                    NaN     active
# ...                                                  ...        ...
# 54281                                                NaN     active
# 54282                                                NaN     active
# 54283                                                NaN     active
# 54284  Asesoría, asesoramiento financiero, mercantil,...     active
# 54285  (CNAE 9319)ORGANIZACION EVENTOS,CAMPUS,ACTIVID...     active
#
#                                                 name          date_updated  \
# 0                      ADEN FINANCIERO ASEGURADOR SL  2009-05-27T00:00:00Z
# 1                         FABRICACION DE BISAGRAS SA  2012-03-29T00:00:00Z
# 2                                    TUBOS MARIÑO SA  2013-10-09T00:00:00Z
# 3                                  ALAS-ALUMINIUM SA  2012-10-08T00:00:00Z
# 4      R.C. INFORMATICA Y SOFTWARE SOCIEDAD LIMITADA  2011-09-17T00:00:00Z
# ...                                              ...                   ...
# 54281                               NOVOCAT FARMA SA  2021-04-09T00:00:00Z
# 54282                  MUEBLES EL PALACIO SA LABORAL  2021-04-05T00:00:00Z
# 54283                     SEMILLEROS FUENTE ALAMO SL  2021-04-13T00:00:00Z
# 54284          GESTYSA EMPRESARIAL SOCIEDAD LIMITADA  2021-04-12T00:00:00Z
# 54285                               VITOGO SPORTS SL  2021-04-09T00:00:00Z
#
#        ...                                      Announcements  \
# 0      ...  ({'text': 'Cambio del Organo de Administración...
# 1      ...  ({'text': 'Procedimiento concursal 145.8/2009....
# 2      ...  ({'text': 'Procedimiento concursal 530/2010. F...
# 3      ...  ({'text': 'Procedimiento concursal 0000044/201...
# 4      ...  {'text': 'Conforme al artículo 274.5 de la Ley...
# ...    ...                                                ...
# 54281  ...  {'text': 'JUZGADO SOCIAL 3 DE SANTIAGO DE COMP...
# 54282  ...  {'text': 'DECLARACION DE SITUACION DE INSOLVEN...
# 54283  ...  {'text': 'Mandamiento remitido por el Juzgado ...
# 54284  ...  {'text': 'Por Decreto 86/2020 de fecha 27/02/2...
# 54285  ...  {'text': 'JUZGADO SOCIAL 30 DE BARCELONA, RESO...
#
#                                                        0  \
# 0      {'text': 'Cambio del Organo de Administración:...
# 1      {'text': 'Procedimiento concursal 145.8/2009. ...
# 2      {'text': 'Procedimiento concursal 530/2010. Fe...
# 3      {'text': 'Procedimiento concursal 0000044/2011...
# 4                                                    NaN
# ...                                                  ...
# 54281                                                NaN
# 54282                                                NaN
# 54283                                                NaN
# 54284                                                NaN
# 54285                                                NaN
#
#                                                        1  \
# 0      {'text': 'La realización de actividades de con...
# 1      {'text': 'Procedimiento concursal 145.8/2009. ...
# 2      {'text': 'Procedimiento concursal 530/2010. FI...
# 3      {'text': 'Procedimiento concursal 0000044/2011...
# 4                                                    NaN
# ...                                                  ...
# 54281                                                NaN
# 54282                                                NaN
# 54283                                                NaN
# 54284                                                NaN
# 54285                                                NaN
#
#                                                        2  \
# 0                                                    NaN
# 1                                                    NaN
# 2      {'text': 'Procedimiento concursal 530/2010. FI...
# 3      {'text': 'Procedimiento concursal 0000044/2011...
# 4                                                    NaN
# ...                                                  ...
# 54281                                                NaN
# 54282                                                NaN
# 54283                                                NaN
# 54284                                                NaN
# 54285                                                NaN
#
#                                                        3    4    5    6    7  \
# 0                                                    NaN  NaN  NaN  NaN  NaN
# 1                                                    NaN  NaN  NaN  NaN  NaN
# 2                                                    NaN  NaN  NaN  NaN  NaN
# 3      {'text': 'Procedimiento concursal 0000044/2011...  NaN  NaN  NaN  NaN
# 4                                                    NaN  NaN  NaN  NaN  NaN
# ...                                                  ...  ...  ...  ...  ...
# 54281                                                NaN  NaN  NaN  NaN  NaN
# 54282                                                NaN  NaN  NaN  NaN  NaN
# 54283                                                NaN  NaN  NaN  NaN  NaN
# 54284                                                NaN  NaN  NaN  NaN  NaN
# 54285                                                NaN  NaN  NaN  NaN  NaN
#
#                                                     text
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      Conforme al artículo 274.5 de la Ley de Proced...
# ...                                                  ...
# 54281  JUZGADO SOCIAL 3 DE SANTIAGO DE COMPOSTELA, RE...
# 54282  DECLARACION DE SITUACION DE INSOLVENCIA PARCIA...
# 54283  Mandamiento remitido por el Juzgado de lo Soci...
# 54284  Por Decreto 86/2020 de fecha 27/02/21 que es f...
# 54285  JUZGADO SOCIAL 30 DE BARCELONA, RESOLUCION FIR...
#
# [54286 rows x 22 columns]

# %%
df_full[df_full.status = "dissolved"]
# Out:
#   File "<ipython-input-62-dfe51bb9a1f3>", line 1
#     df_full[df_full.status = "dissolved"]
#                            ^
# SyntaxError: invalid syntax

# %%
df_full.to_csv(filename + '.csv')

# %%
df_full.shape
# Out:
# (54286, 22)

# %%
df_full
# Out:
#                        date  \
# 0      2009-05-27T00:00:00Z
# 1      2009-06-11T00:00:00Z
# 2      2010-11-02T00:00:00Z
# 3      2011-03-16T00:00:00Z
# 4      2010-06-09T00:00:00Z
# ...                     ...
# 54281  2021-04-09T00:00:00Z
# 54282  2021-04-05T00:00:00Z
# 54283  2021-04-13T00:00:00Z
# 54284  2021-04-12T00:00:00Z
# 54285  2021-04-09T00:00:00Z
#
#                                                  company  \
# 0      [{'slug_company': 'aden-financiero-asegurador'...
# 1      [{'slug_company': 'fabricacion-de-bisagras', '...
# 2      [{'slug_company': 'tubos-mariño', 'province': ...
# 3      [{'slug_company': 'alas-aluminium', 'province'...
# 4      [{'slug_company': 'r-c-informatica-y-software'...
# ...                                                  ...
# 54281  [{'slug_company': 'novocat-farma', 'province':...
# 54282  [{'slug_company': 'muebles-el-palacio-sa-labor...
# 54283  [{'slug_company': 'semilleros-fuente-alamo', '...
# 54284  [{'slug_company': 'gestysa-empresarial', 'prov...
# 54285  [{'slug_company': 'vitogo-sports', 'province':...
#
#                                            announcements  \
# 0      [{'text': 'Cambio del Organo de Administración...
# 1      [{'text': 'Procedimiento concursal 145.8/2009....
# 2      [{'text': 'Procedimiento concursal 530/2010. F...
# 3      [{'text': 'Procedimiento concursal 0000044/201...
# 4      [{'text': 'Conforme al artículo 274.5 de la Le...
# ...                                                  ...
# 54281  [{'text': 'JUZGADO SOCIAL 3 DE SANTIAGO DE COM...
# 54282  [{'text': 'DECLARACION DE SITUACION DE INSOLVE...
# 54283  [{'text': 'Mandamiento remitido por el Juzgado...
# 54284  [{'text': 'Por Decreto 86/2020 de fecha 27/02/...
# 54285  [{'text': 'JUZGADO SOCIAL 30 DE BARCELONA, RES...
#
#                                                  Company  \
# 0      {'slug_company': 'aden-financiero-asegurador',...
# 1      {'slug_company': 'fabricacion-de-bisagras', 'p...
# 2      {'slug_company': 'tubos-mariño', 'province': '...
# 3      {'slug_company': 'alas-aluminium', 'province':...
# 4      {'slug_company': 'r-c-informatica-y-software',...
# ...                                                  ...
# 54281  {'slug_company': 'novocat-farma', 'province': ...
# 54282  {'slug_company': 'muebles-el-palacio-sa-labora...
# 54283  {'slug_company': 'semilleros-fuente-alamo', 'p...
# 54284  {'slug_company': 'gestysa-empresarial', 'provi...
# 54285  {'slug_company': 'vitogo-sports', 'province': ...
#
#                         slug_company   province  \
# 0         aden-financiero-asegurador     Madrid
# 1            fabricacion-de-bisagras  Barcelona
# 2                       tubos-mariño    Cáceres
# 3                     alas-aluminium   Asturias
# 4         r-c-informatica-y-software       Jaén
# ...                              ...        ...
# 54281                  novocat-farma  Barcelona
# 54282  muebles-el-palacio-sa-laboral    Segovia
# 54283        semilleros-fuente-alamo     Murcia
# 54284            gestysa-empresarial    Granada
# 54285                  vitogo-sports  Barcelona
#
#                                                  purpose     status  \
# 0      La realización de actividades de consultoría y...     active
# 1                                                    NaN     active
# 2                                                    NaN   inactive
# 3                                                    NaN  dissolved
# 4                                                    NaN     active
# ...                                                  ...        ...
# 54281                                                NaN     active
# 54282                                                NaN     active
# 54283                                                NaN     active
# 54284  Asesoría, asesoramiento financiero, mercantil,...     active
# 54285  (CNAE 9319)ORGANIZACION EVENTOS,CAMPUS,ACTIVID...     active
#
#                                                 name          date_updated  \
# 0                      ADEN FINANCIERO ASEGURADOR SL  2009-05-27T00:00:00Z
# 1                         FABRICACION DE BISAGRAS SA  2012-03-29T00:00:00Z
# 2                                    TUBOS MARIÑO SA  2013-10-09T00:00:00Z
# 3                                  ALAS-ALUMINIUM SA  2012-10-08T00:00:00Z
# 4      R.C. INFORMATICA Y SOFTWARE SOCIEDAD LIMITADA  2011-09-17T00:00:00Z
# ...                                              ...                   ...
# 54281                               NOVOCAT FARMA SA  2021-04-09T00:00:00Z
# 54282                  MUEBLES EL PALACIO SA LABORAL  2021-04-05T00:00:00Z
# 54283                     SEMILLEROS FUENTE ALAMO SL  2021-04-13T00:00:00Z
# 54284          GESTYSA EMPRESARIAL SOCIEDAD LIMITADA  2021-04-12T00:00:00Z
# 54285                               VITOGO SPORTS SL  2021-04-09T00:00:00Z
#
#        ...                                      Announcements  \
# 0      ...  ({'text': 'Cambio del Organo de Administración...
# 1      ...  ({'text': 'Procedimiento concursal 145.8/2009....
# 2      ...  ({'text': 'Procedimiento concursal 530/2010. F...
# 3      ...  ({'text': 'Procedimiento concursal 0000044/201...
# 4      ...  {'text': 'Conforme al artículo 274.5 de la Ley...
# ...    ...                                                ...
# 54281  ...  {'text': 'JUZGADO SOCIAL 3 DE SANTIAGO DE COMP...
# 54282  ...  {'text': 'DECLARACION DE SITUACION DE INSOLVEN...
# 54283  ...  {'text': 'Mandamiento remitido por el Juzgado ...
# 54284  ...  {'text': 'Por Decreto 86/2020 de fecha 27/02/2...
# 54285  ...  {'text': 'JUZGADO SOCIAL 30 DE BARCELONA, RESO...
#
#                                                        0  \
# 0      {'text': 'Cambio del Organo de Administración:...
# 1      {'text': 'Procedimiento concursal 145.8/2009. ...
# 2      {'text': 'Procedimiento concursal 530/2010. Fe...
# 3      {'text': 'Procedimiento concursal 0000044/2011...
# 4                                                    NaN
# ...                                                  ...
# 54281                                                NaN
# 54282                                                NaN
# 54283                                                NaN
# 54284                                                NaN
# 54285                                                NaN
#
#                                                        1  \
# 0      {'text': 'La realización de actividades de con...
# 1      {'text': 'Procedimiento concursal 145.8/2009. ...
# 2      {'text': 'Procedimiento concursal 530/2010. FI...
# 3      {'text': 'Procedimiento concursal 0000044/2011...
# 4                                                    NaN
# ...                                                  ...
# 54281                                                NaN
# 54282                                                NaN
# 54283                                                NaN
# 54284                                                NaN
# 54285                                                NaN
#
#                                                        2  \
# 0                                                    NaN
# 1                                                    NaN
# 2      {'text': 'Procedimiento concursal 530/2010. FI...
# 3      {'text': 'Procedimiento concursal 0000044/2011...
# 4                                                    NaN
# ...                                                  ...
# 54281                                                NaN
# 54282                                                NaN
# 54283                                                NaN
# 54284                                                NaN
# 54285                                                NaN
#
#                                                        3    4    5    6    7  \
# 0                                                    NaN  NaN  NaN  NaN  NaN
# 1                                                    NaN  NaN  NaN  NaN  NaN
# 2                                                    NaN  NaN  NaN  NaN  NaN
# 3      {'text': 'Procedimiento concursal 0000044/2011...  NaN  NaN  NaN  NaN
# 4                                                    NaN  NaN  NaN  NaN  NaN
# ...                                                  ...  ...  ...  ...  ...
# 54281                                                NaN  NaN  NaN  NaN  NaN
# 54282                                                NaN  NaN  NaN  NaN  NaN
# 54283                                                NaN  NaN  NaN  NaN  NaN
# 54284                                                NaN  NaN  NaN  NaN  NaN
# 54285                                                NaN  NaN  NaN  NaN  NaN
#
#                                                     text
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      Conforme al artículo 274.5 de la Ley de Proced...
# ...                                                  ...
# 54281  JUZGADO SOCIAL 3 DE SANTIAGO DE COMPOSTELA, RE...
# 54282  DECLARACION DE SITUACION DE INSOLVENCIA PARCIA...
# 54283  Mandamiento remitido por el Juzgado de lo Soci...
# 54284  Por Decreto 86/2020 de fecha 27/02/21 que es f...
# 54285  JUZGADO SOCIAL 30 DE BARCELONA, RESOLUCION FIR...
#
# [54286 rows x 22 columns]

# %% [markdown]
# ## 2. Read Flat Data

# %%
filename = "data/insolvencias_2021.04.20"

df = pd.read_csv(filename + '.csv', low_memory = False)

# %%
df.shape
# Out:
# (54286, 23)

# %%
df["day"]= [x[:7] for x in df["date"]]
df.sort_values(by = ["day"],inplace = True)
df.head(10)
# Out:
#        Unnamed: 0                  date  \
# 9               9  2009-02-24T00:00:00Z
# 11             11  2009-03-17T00:00:00Z
# 0               0  2009-05-27T00:00:00Z
# 1               1  2009-06-11T00:00:00Z
# 7               7  2009-06-11T00:00:00Z
# 20775       20775  2009-11-04T00:00:00Z
# 17             17  2010-01-18T00:00:00Z
# 8               8  2010-06-29T00:00:00Z
# 4               4  2010-06-09T00:00:00Z
# 20             20  2010-07-16T00:00:00Z
#
#                                                  company  \
# 9      [{'slug_company': 'nortel-networks-hispania', ...
# 11     [{'slug_company': 'milenio-foods', 'province':...
# 0      [{'slug_company': 'aden-financiero-asegurador'...
# 1      [{'slug_company': 'fabricacion-de-bisagras', '...
# 7      [{'slug_company': 'fabricacion-de-bisagras', '...
# 20775  [{'slug_company': 'agricola-le-seigle', 'provi...
# 17     [{'slug_company': 'lehman-brothers-internation...
# 8      [{'slug_company': 'mg-rover-españa', 'province...
# 4      [{'slug_company': 'r-c-informatica-y-software'...
# 20     [{'slug_company': 'o-d-l-de-guevara-y-zabala',...
#
#                                            announcements  \
# 9      [{'text': 'Procedimiento concursal 535/2009. F...
# 11     [{'text': 'Procedimiento concursal 660/2008. F...
# 0      [{'text': 'Cambio del Organo de Administración...
# 1      [{'text': 'Procedimiento concursal 145.8/2009....
# 7      [{'text': 'Procedimiento concursal 145.8/2009....
# 20775  [{'text': 'de insolvencia con carácter provisi...
# 17     [{'text': 'MANDAMIENTO ORDENANDO LA INSCRIPCIO...
# 8      [{'text': 'Procedimiento concursal 2376/2005. ...
# 4      [{'text': 'Conforme al artículo 274.5 de la Le...
# 20     [{'text': 'Don José Antonio Ibarra Zorrilla ha...
#
#                                                  Company  \
# 9      {'slug_company': 'nortel-networks-hispania', '...
# 11     {'slug_company': 'milenio-foods', 'province': ...
# 0      {'slug_company': 'aden-financiero-asegurador',...
# 1      {'slug_company': 'fabricacion-de-bisagras', 'p...
# 7      {'slug_company': 'fabricacion-de-bisagras', 'p...
# 20775  {'slug_company': 'agricola-le-seigle', 'provin...
# 17     {'slug_company': 'lehman-brothers-internationa...
# 8      {'slug_company': 'mg-rover-españa', 'province'...
# 4      {'slug_company': 'r-c-informatica-y-software',...
# 20     {'slug_company': 'o-d-l-de-guevara-y-zabala', ...
#
#                                slug_company   province  \
# 9                  nortel-networks-hispania     Madrid
# 11                            milenio-foods   Alicante
# 0                aden-financiero-asegurador     Madrid
# 1                   fabricacion-de-bisagras  Barcelona
# 7                   fabricacion-de-bisagras  Barcelona
# 20775                    agricola-le-seigle    Sevilla
# 17     lehman-brothers-international-europe     Madrid
# 8                           mg-rover-españa     Madrid
# 4                r-c-informatica-y-software       Jaén
# 20                o-d-l-de-guevara-y-zabala    Vizcaya
#
#                                                  purpose    status  \
# 9                                                    NaN  inactive
# 11                                                   NaN    active
# 0      La realización de actividades de consultoría y...    active
# 1                                                    NaN    active
# 7                                                    NaN    active
# 20775  Restaurantes, Bares-Cafes y todo tipo de negoc...    active
# 17                                                   NaN  inactive
# 8                                                    NaN  inactive
# 4                                                    NaN    active
# 20                                                   NaN    active
#
#                                                     name  ...  \
# 9                            NORTEL NETWORKS HISPANIA SA  ...
# 11                                      MILENIO FOODS SL  ...
# 0                          ADEN FINANCIERO ASEGURADOR SL  ...
# 1                             FABRICACION DE BISAGRAS SA  ...
# 7                             FABRICACION DE BISAGRAS SA  ...
# 20775               AGRICOLA LE SEIGLE SOCIEDAD LIMITADA  ...
# 17     LEHMAN BROTHERS INTERNATIONAL EUROPE SUCURSAL ...  ...
# 8                                     MG ROVER ESPAÑA SA  ...
# 4          R.C. INFORMATICA Y SOFTWARE SOCIEDAD LIMITADA  ...
# 20           O D L DE GUEVARA Y ZABALA SOCIEDAD LIMITADA  ...
#
#                                                        0  \
# 9      {'text': 'Procedimiento concursal 535/2009. Fe...
# 11                                                   NaN
# 0      {'text': 'Cambio del Organo de Administración:...
# 1      {'text': 'Procedimiento concursal 145.8/2009. ...
# 7      {'text': 'Procedimiento concursal 145.8/2009. ...
# 20775                                                NaN
# 17                                                   NaN
# 8      {'text': 'Procedimiento concursal 2376/2005. F...
# 4                                                    NaN
# 20                                                   NaN
#
#                                                        1  \
# 9      {'text': 'Procedimiento concursal 535/2009. Fe...
# 11                                                   NaN
# 0      {'text': 'La realización de actividades de con...
# 1      {'text': 'Procedimiento concursal 145.8/2009. ...
# 7      {'text': 'El 3.2.09 se nombra administrador co...
# 20775                                                NaN
# 17                                                   NaN
# 8                                  {'text': 'Judicial.'}
# 4                                                    NaN
# 20                                                   NaN
#
#                                                        2  \
# 9      {'text': 'Procedimiento concursal 535/2009. Fe...
# 11                                                   NaN
# 0                                                    NaN
# 1                                                    NaN
# 7                                                    NaN
# 20775                                                NaN
# 17                                                   NaN
# 8      {'text': 'CONFORME A LA RESOLUCION JUDICIAL SO...
# 4                                                    NaN
# 20                                                   NaN
#
#                                                        3  \
# 9      {'text': 'Procedimiento concursal 535/2009. FI...
# 11                                                   NaN
# 0                                                    NaN
# 1                                                    NaN
# 7                                                    NaN
# 20775                                                NaN
# 17                                                   NaN
# 8                                                    NaN
# 4                                                    NaN
# 20                                                   NaN
#
#                                                        4    5    6    7  \
# 9      {'text': 'Procedimiento concursal 535/2009. Fe...  NaN  NaN  NaN
# 11                                                   NaN  NaN  NaN  NaN
# 0                                                    NaN  NaN  NaN  NaN
# 1                                                    NaN  NaN  NaN  NaN
# 7                                                    NaN  NaN  NaN  NaN
# 20775                                                NaN  NaN  NaN  NaN
# 17                                                   NaN  NaN  NaN  NaN
# 8                                                    NaN  NaN  NaN  NaN
# 4                                                    NaN  NaN  NaN  NaN
# 20                                                   NaN  NaN  NaN  NaN
#
#                                                     text      day
# 9                                                    NaN  2009-02
# 11     Procedimiento concursal 660/2008. FIRME: Si, F...  2009-03
# 0                                                    NaN  2009-05
# 1                                                    NaN  2009-06
# 7                                                    NaN  2009-06
# 20775  de insolvencia con carácter provisional, por i...  2009-11
# 17     MANDAMIENTO ORDENANDO LA INSCRIPCION DEL RECON...  2010-01
# 8                                                    NaN  2010-06
# 4      Conforme al artículo 274.5 de la Ley de Proced...  2010-06
# 20     Don José Antonio Ibarra Zorrilla ha sido conde...  2010-07
#
# [10 rows x 24 columns]

# %%
#df = df[df.status == "inactive"]

# %%
df.groupby(['day']).size()
# Out:
# day
# 2009-02      1
# 2009-03      1
# 2009-05      1
# 2009-06      2
# 2009-11      1
#           ...
# 2020-12    307
# 2021-01    263
# 2021-02    324
# 2021-03    454
# 2021-04     99
# Length: 136, dtype: int64

# %%
df_dates = pd.DataFrame(df.groupby(['day']).size()).reset_index("day")
df_dates
# Out:
#          day    0
# 0    2009-02    1
# 1    2009-03    1
# 2    2009-05    1
# 3    2009-06    2
# 4    2009-11    1
# ..       ...  ...
# 131  2020-12  307
# 132  2021-01  263
# 133  2021-02  324
# 134  2021-03  454
# 135  2021-04   99
#
# [136 rows x 2 columns]

# %%
df_dates_cn = df_dates.rename(columns = {0:"recuento_insolvencias", "day":"month"})
df_dates_cn
# Out:
#        month  recuento_insolvencias
# 0    2009-02                      1
# 1    2009-03                      1
# 2    2009-05                      1
# 3    2009-06                      2
# 4    2009-11                      1
# ..       ...                    ...
# 131  2020-12                    307
# 132  2021-01                    263
# 133  2021-02                    324
# 134  2021-03                    454
# 135  2021-04                     99
#
# [136 rows x 2 columns]

# %%
chart = alt.Chart(df_dates_cn).mark_line().encode(
    x='month:T',
    y='recuento_insolvencias:Q'
).properties(
    width=800,
    height=300
)
chart.save('img/insolvencias_2021.04.20.html')

chart
# Out:
# alt.Chart(...)

# %%
export_file = "img/insolvencias_2021.04.20"

# %%
###   GENERATE INTERACTIVE PLOT   ###
source = df_dates_cn

# Create a selection that chooses the nearest point & selects based on x-value
nearest = alt.selection(type='single', nearest=True, on='mouseover',
                        fields=['month'], empty='none')

# The basic line
line = alt.Chart(source).mark_line(interpolate='basis').encode(
    x='month:T',
    y='recuento_insolvencias:Q'
)

# Transparent selectors across the chart. This is what tells us
# the x-value of the cursor
selectors = alt.Chart(source).mark_point().encode(
    x='month:T',
    opacity=alt.value(0),
).add_selection(
    nearest
)

# Draw points on the line, and highlight based on selection
points = line.mark_point().encode(
    opacity=alt.condition(nearest, alt.value(1), alt.value(0))
)

# Draw text labels near the points, and highlight based on selection
text = line.mark_text(align='left', dx=2, dy=-2).encode(
    text=alt.condition(nearest, 'recuento_insolvencias:Q', alt.value(' '))
)

# Draw a rule at the location of the selection
rules = alt.Chart(source).mark_rule(color='gray').encode(
    x='month:T',
).transform_filter(
    nearest
)

# Put the five layers into a chart and bind the data
chart2 = alt.layer(
    line, selectors, points, rules, text
).properties(
    width=600, height=300
)

chart2.save(export_file + '_interactive.html')
print("Interactive plot has been successfully saved at " + export_file + '_interactive.html')

chart2
# Out:
# Interactive plot has been successfully saved at img/insolvencias_2021.04.20_interactive.html
# alt.LayerChart(...)

# %%
###    GENERATE INTERACTIVE CHANGING TOOLTIP      ###

source = df_dates_cn

# Create a selection that chooses the nearest point & selects based on x-value
nearest = alt.selection(type='single', nearest=True, on='mouseover',
                        fields=['month'], empty='none')

# The basic line
line = alt.Chart(source).mark_line(interpolate='basis').encode(
    x='month:O',
    y='recuento_insolvencias:Q'
)

# Transparent selectors across the chart. This is what tells us
# the x-value of the cursor
selectors = alt.Chart(source).mark_point().encode(
    x='month:O',
    opacity=alt.value(0),
).add_selection(
    nearest
)

# Draw points on the line, and highlight based on selection
points = line.mark_point().encode(
    opacity=alt.condition(nearest, alt.value(1), alt.value(0))
)

# Draw text labels near the points, and highlight based on selection
text = line.mark_text(align='left', dx=2, dy=-2).encode(
    text=alt.condition(nearest, 'month:O', alt.value(' '))
)

# Draw a rule at the location of the selection
rules = alt.Chart(source).mark_rule(color='gray').encode(
    x='month:O',
).transform_filter(
    nearest
)

# Put the five layers into a chart and bind the data
chart3 = alt.layer(
    line, selectors, points, rules, text
).properties(
    width=600, height=300
)

chart3.save(export_file + '_interactive_text.html')
print("Interactive plot has been successfully saved at " + export_file + '_interactive_text.html')

chart3
# Out:
# Interactive plot has been successfully saved at img/insolvencias_2021.04.20_interactive_text.html
# alt.LayerChart(...)
